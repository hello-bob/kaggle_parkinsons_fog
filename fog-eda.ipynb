# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/sample_submission.csv
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/subjects.csv
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/tasks.csv
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/defog_metadata.csv
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/daily_metadata.csv
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/events.csv
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/tdcsfog_metadata.csv
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/unlabeled/48b636e0f5.parquet
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/unlabeled/9fb7805d99.parquet
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/unlabeled/e658b0aa3d.parquet
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/unlabeled/1c3719ea59.parquet
# /kaggle/input/tlvmc-parkinsons-freezing-gait-prediction/unlabeled/164adaed7b.parquet
# ...

# %%
import pandas as pd
import numpy as np
import os

os.chdir('/kaggle/input/tlvmc-parkinsons-freezing-gait-prediction')

# %%
subjects = pd.read_csv('subjects.csv')
events = pd.read_csv('events.csv')
home_meta = pd.read_csv('defog_metadata.csv')
daily_meta = pd.read_csv('tdcsfog_metadata.csv')
lab_meta = pd.read_csv('tdcsfog_metadata.csv')

# %%
# Profiling subjects
"""
136 unique subjects. 65 belong to home, hence 71 belong to lab dataset
Majority male, and >=68 y/o. 
At most 2 visits, what do these visits represent?
Generally parkinsons
Most cases were not recently diagnosed. 
"""
subjects.describe(include='all')
# Out:
#        Subject       Visit         Age  Sex  YearsSinceDx  UPDRSIII_On  \
# count      173  111.000000  173.000000  173    173.000000   172.000000
# unique     136         NaN         NaN    2           NaN          NaN
# top     00f674         NaN         NaN    M           NaN          NaN
# freq         2         NaN         NaN  121           NaN          NaN
# mean       NaN    1.369369   67.763006  NaN     10.383931    34.273256
# std        NaN    0.484823    7.972075  NaN      6.289191    12.732552
# min        NaN    1.000000   28.000000  NaN      0.420000     5.000000
# 25%        NaN    1.000000   62.000000  NaN      6.000000    25.000000
# 50%        NaN    1.000000   68.000000  NaN      9.000000    35.000000
# 75%        NaN    2.000000   73.000000  NaN     15.000000    42.250000
# max        NaN    2.000000   94.000000  NaN     30.000000    79.000000
#
#         UPDRSIII_Off       NFOGQ
# count     132.000000  173.000000
# unique           NaN         NaN
# ...

# %%
# Profiling lab_meta
"""
Up to 20 visits? Minimum of 2.
"""
lab_meta.describe(include='all')
# Out:
#                 Id Subject       Visit        Test Medication
# count          833     833  833.000000  833.000000        833
# unique         833      62         NaN         NaN          2
# top     003f117e14  f2c8aa         NaN         NaN         on
# freq             1      24         NaN         NaN        536
# mean           NaN     NaN    6.460984    1.974790        NaN
# std            NaN     NaN    6.171914    0.813402        NaN
# min            NaN     NaN    2.000000    1.000000        NaN
# 25%            NaN     NaN    2.000000    1.000000        NaN
# 50%            NaN     NaN    4.000000    2.000000        NaN
# 75%            NaN     NaN    5.000000    3.000000        NaN
# max            NaN     NaN   20.000000    3.000000        NaN

# %%
# Profiling home_meta
home_meta.describe(include='all')
# Out:
#                 Id Subject       Visit Medication
# count          137     137  137.000000        137
# unique         137      45         NaN          2
# top     02ab235146  5d9cae         NaN         on
# freq             1       4         NaN         69
# mean           NaN     NaN    1.489051        NaN
# std            NaN     NaN    0.501715        NaN
# min            NaN     NaN    1.000000        NaN
# 25%            NaN     NaN    1.000000        NaN
# 50%            NaN     NaN    1.000000        NaN
# 75%            NaN     NaN    2.000000        NaN
# max            NaN     NaN    2.000000        NaN

# %% [markdown]
# ## Single Subject
# - How many data points?
# - When do the events occur?
# - Are the changes in acc readings for each type of event different?
# - Do patterns vary widely when on and off medications?

# %%
# Profiling one subject from the lab dataset

# %%
# Profiling one subject from the home dataset

# %%
# Profiling one subject from the daily dataset (no PD)

# %%
# Profiling one subject from the daily dataset (with PD)

# %% [markdown]
# ## Multiple Subjects
# - Do people within each dataset have the same trends?
# - Will there be difference of patterns between age, sex and severity of PD (which score to use, and how to classify?)
# - Are the changes in acc readings for each type of event between people different?

# %%
# Comparing subjects from the lab dataset

# %%
# Comparing subjects from the home dataset

# %%
# Comparing subjects from the daily dataset (no PD)

# %%
# Comparing subjects from the daily dataset (with PD)

# %% [markdown]
# ## All subjects
# - Frequency of events between datasets
# - Frequency of types of events between datasets

# %%
#
